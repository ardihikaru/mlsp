# %%
import numpy as np
from matplotlib import pyplot as plt
import time

# %%
# from hw4.libs.dataset import Dataset
from finalproject.libs.face_dataset import FaceDataset

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread("./finalproject/datasets/1/0.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread("./finalproject/datasets/original_sizes/370_Face_Id0.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread("./finalproject/datasets/original_sizes/372_Face_Id0.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread("./finalproject/datasets/original_sizes/374_Face_Id0.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
img=mpimg.imread("./finalproject/datasets/original_sizes/375_Face_Id0.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
timestamp = time.time()
# dataset = Dataset()
fcdataset = FaceDataset()
feat_imgs = fcdataset.get_img_features()
# fives = dataset.get_5s()
print("time used to Load and filter digit 5s dataset：", round((time.time() - timestamp), 2), 's')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-914cba7d0e44> in <module>
#       1 timestamp = time.time()
#       2 # dataset = Dataset()
# ----> 3 fcdataset = FaceDataset()
#       4 feat_imgs = fcdataset.get_img_features()
#       5 # fives = dataset.get_5s()
#
# ~/devel/nctu/mlsp/finalproject/libs/face_dataset.py in __init__(self, img_size, N, img_dataset_path, man_dataset)
#      23         else:
#      24             self.data = np.zeros((self.D, self.N))
# ---> 25             self.__load_default_imgs()
#      26
#      27     def __load_default_imgs(self):
#
# ~/devel/nctu/mlsp/finalproject/libs/face_dataset.py in __load_default_imgs(self)
#      31         for filename in glob.glob(img_data):
#      32             self.img = np.asarray(imread(filename))
# ---> 33             self.data[:, i] = np.ravel(self.img)
#      34             i = i + 1
# ...

# %%
print(" >> feat_imgs Shape = ", feat_imgs.shape)
# print(" >> fives Shape = ", fives.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e023acc42a8f> in <module>
# ----> 1 print(" >> feat_imgs Shape = ", feat_imgs.shape)
#       2 # print(" >> fives Shape = ", fives.shape)
#       3
#
# NameError: name 'feat_imgs' is not defined

# %%
# Plot Matrix (9, 8) is due to known collected digit 5s; total = 72 (Manually defined)
fig, numplt = plt.subplots(3, 3, subplot_kw=dict(xticks=[], yticks=[]))
for i, axis in enumerate(numplt.flat):
    axis.imshow(np.reshape(feat_imgs[:, i], (112, 112), 'C'))
    # axis.imshow(np.reshape(fives[:, i], (28, 28), 'F'))
